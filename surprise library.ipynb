# %% [markdown]
# # Surprise library for Collaborative Filtering - Recommender System

# %% [markdown]
# The name Surprise stands for Simple Python Recommendation System Engine.
# Surprise is an easy-to-use Python library for building and testing recommender systems.
#
# Users can use both built-in datasets (Movielens, Jester), and their own custom datasets.
#
#
# * Provide various ready-to-use prediction algorithms such as baseline algorithms, neighborhood methods, matrix factorization-based ( SVD, PMF, SVD++, NMF), and many others.
#
# * Provide various similarity measures (cosine, MSD, pearson…) are built-in.
#
# * Provide tools to evaluate, analyse and compare the algorithms’ performance. Cross-validation procedures can be run very easily using powerful CV iterators
#
#
# **Please note that surprise does not support implicit ratings or content-based information.**
#
#
# **What Surprise library can do on build recommender system models?**
#
# 1. data
#
# 2. Split dataset into train and test sebsets
#
# 3. Build models by using different algorithms
#
# 4. Cross validate
#
# 5. Tune hyperparameters
#
# 6. Model evaluation
#
#
# References:
#
# http://surpriselib.com/
#
# Surprise’ documentation: https://surprise.readthedocs.io/en/stable/
#
#
#
# ## Part 1: Installation

# %%
$ pip install numpy
$ pip install scikit-surprise
 
    OR 
    
$ conda install -c conda-forge scikit-surprise

# %% [markdown]
# ## Part 2: Dataset module
#
# Three built-in datasets are available:
#
# 1. The movielens-100k dataset.
#
# 2. The movielens-1m dataset.
#
# 3. The Jester dataset 2.

# %%
from surprise import Dataset

# Load the movielens-100k dataset
data = Dataset.load_builtin('ml-100k')

import pandas as pd
df = pd.DataFrame(data.__dict__['raw_ratings'], columns=['user_id','item_id','rating','timestamp'])
df.head(10)
# Out:
#   user_id item_id  rating  timestamp
# 0     196     242     3.0  881250949
# 1     186     302     3.0  891717742
# 2      22     377     1.0  878887116
# 3     244      51     2.0  880606923
# 4     166     346     1.0  886397596
# 5     298     474     4.0  884182806
# 6     115     265     2.0  881171488
# 7     253     465     5.0  891628467
# 8     305     451     3.0  886324817
# 9       6      86     3.0  883603013

# %% [markdown]
# ## Part 3: Prediction_algorithms package
#
# ### 1. Basic algorithms:
#
# `NormalPredictor`
#
# NormalPredictor algorithm predicts a random rating based on the distribution of the training set, which is assumed to be normal. This is one of the most basic algorithms that do not do much work.
#
# `BaselineOnly`
#
# BaselineOnly algorithm predicts the baseline estimate for given user and item.
#
# ### 2. k-NN algorithms
#
# `KNNBasic`
#
# KNNBasic is a basic collaborative filtering algorithm.
#
# `KNNWithMeans`
#
# KNNWithMeans is basic collaborative filtering algorithm, taking into account the mean ratings of each user.
#
# `KNNWithZScore`
#
# KNNWithZScore is a basic collaborative filtering algorithm, taking into account the z-score normalization of each user.
#
# `KNNBaseline`
#
# KNNBaseline is a basic collaborative filtering algorithm taking into account a baseline rating.
#
# ### 3. Matrix Factorization-based algorithms
#
# `SVD`
#
# SVD algorithm is equivalent to Probabilistic Matrix Factorization.
#
# `SVDpp`
#
# The SVDpp algorithm is an extension of SVD that takes into account implicit ratings.
#
# `NMF`
#
# NMF is a collaborative filtering algorithm based on Non-negative Matrix Factorization. It is very similar with SVD.
#
# ### 4. Other Collaborative Filtering Algorithms
#
# `Slope One`
#
# SlopeOne is a straightforward implementation of the SlopeOne algorithm.
#
# `Co-clustering`
#
# Coclustering is a collaborative filtering algorithm based on co-clustering.
#
# Reference: https://towardsdatascience.com/building-and-testing-recommender-systems-with-surprise-step-by-step-d4ba702ef80b
#
# ## Part 4: Hyperparameters Optimization - GridSearchCV / RandomizedSearchCV
#
# 1. The `GridSearchCV` class computes accuracy metrics for an algorithm on various combinations of parameters, over a cross-validation procedure. This is useful for finding the best set of parameters for a prediction algorithm.
#
# **Default parameters:**
#
# surprise.model_selection.search.GridSearchCV(algo_class, param_grid, measures=[u'rmse', u'mae'], cv=None, refit=False, return_train_measures=False, n_jobs=1, pre_dispatch=u'2*n_jobs', joblib_verbose=0)
#
#
# 2. The `RandomizedSearchCV` class computes accuracy metrics for an algorithm on various combinations of parameters, over a cross-validation procedure. As opposed to GridSearchCV, which uses an exhaustive combinatorial approach, RandomizedSearchCV samples randomly from the parameter space.
#
# **Default parameters:**
#
# surprise.model_selection.search.RandomizedSearchCV(algo_class, param_distributions, n_iter=10, measures=[u'rmse', u'mae'], cv=None, refit=False, return_train_measures=False, n_jobs=1, pre_dispatch=u'2*n_jobs', random_state=None, joblib_verbose=0)
#
# **Import library:**
#
# from surprise.model_selection import GridSearchCV
#
# from surprise.model_selection import RandomizedSearchCV
#
#
# More details: https://surprise.readthedocs.io/en/stable/model_selection.html
#
#
#
# ## Part 5: Accuracy module
#
# The `surprise.accuracy` module provides tools for computing accuracy metrics on a set of predictions.
#
# Available accuracy metrics:
#
# `rmse`	Compute RMSE (Root Mean Squared Error).
#
# `mse`	Compute MSE (Mean Squared Error).
#
# `mae`	Compute MAE (Mean Absolute Error).
#
# `fcp`	Compute FCP (Fraction of Concordant Pairs).
#
# **Evaluate model in the train datset:**
#
# from surprise.model_selection import `cross_validate`
#
# **Split dataset into train and test subsets:**
#
# from surprise.model_selection import `train_test_split`

# %%
from surprise.model_selection import cross_validate
from surprise import NormalPredictor
from surprise import KNNBasic
from surprise import KNNWithMeans
from surprise import KNNWithZScore
from surprise import KNNBaseline
from surprise import SVD
from surprise import BaselineOnly
from surprise import SVDpp
from surprise import NMF
from surprise import SlopeOne
from surprise import CoClustering
from surprise.accuracy import rmse
from surprise import accuracy
from surprise.model_selection import train_test_split

# %% [markdown]
# ## Part 6: Example
#
# I'll use the movielens-100k dataset as an example.
#
#
# Helpful articles:
#
# https://bmanohar16.github.io/blog/recsys-evaluation-in-surprise
#
# https://github.com/susanli2016/Machine-Learning-with-Python/blob/master/Building%20Recommender%20System%20with%20Surprise.ipynb

# %%
# code from https://github.com/susanli2016/Machine-Learning-with-Python/blob/master/Building%20Recommender%20System%20with%20Surprise.ipynb
# use rmse as our accuracy metric for the predictions.

benchmark = []
# Iterate over all algorithms
for algorithm in [SVD(), SVDpp(), SlopeOne(), NMF(), NormalPredictor(), KNNBaseline(), KNNBasic(), KNNWithMeans(), KNNWithZScore(), BaselineOnly(), CoClustering()]:
    # Perform 3-fold cross validation
    results = cross_validate(algorithm, data, measures=['RMSE'], cv=3, verbose=False)
    
    # Get results & append algorithm name
    tmp = pd.DataFrame.from_dict(results).mean(axis=0)
    tmp = tmp.append(pd.Series([str(algorithm).split(' ')[0].split('.')[-1]], index=['Algorithm']))
    benchmark.append(tmp)
# Out:
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...

# %%
surprise_results = pd.DataFrame(benchmark).set_index('Algorithm').sort_values('test_rmse')
surprise_results
# Out:
#                  test_rmse    fit_time  test_time
# Algorithm
# SVDpp             0.926970  399.482269  19.333255
# KNNBaseline       0.936670    1.154948  16.031015
# SVD               0.946027    9.619627   1.052136
# BaselineOnly      0.946891    1.959221   1.091207
# SlopeOne          0.949064    1.303426   9.972574
# KNNWithMeans      0.955356    0.792057  12.801589
# KNNWithZScore     0.955367    0.835488  18.919293
# NMF               0.974776    9.044773   0.567050
# CoClustering      0.979337    4.955861   0.884986
# KNNBasic          0.989335    0.769511  16.129125
# NormalPredictor   1.518711    0.246425   0.662745

# %% [markdown]
# ###  Tuning Hyperparameters - GridSearchCV

# %%
# code from https://www.kaggle.com/sunyuanxi/surprise
from surprise.model_selection import GridSearchCV
from surprise.model_selection import RandomizedSearchCV


param_grid = {'n_factors': [70, 80, 90, 100, 110, 120, 130, 140, 150, 160], 'n_epochs': [100], 'reg_all': [0.1]}

#gs_svd = GridSearchCV(SVD, param_grid, measures=['rmse'], cv=3)
gs_svd = RandomizedSearchCV(SVD, param_grid, measures=['rmse'], cv=3)


gs_svd.fit(data)
svd = gs_svd.best_estimator['rmse']

print(gs_svd.best_score['rmse'])
print(gs_svd.best_params['rmse'])
# Out:
# 0.9184025288375731
# {'n_factors': 100, 'n_epochs': 100, 'reg_all': 0.1}

# %%
from surprise.model_selection import train_test_split
from surprise import accuracy

trainset, testset = train_test_split(data, test_size=0.25)

algo = SVD(n_factors= 100, n_epochs= 100, reg_all= 0.1)
algo.fit(trainset)

cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=3, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.9151  0.9199  0.9206  0.9185  0.0024
# MAE (testset)     0.7239  0.7253  0.7283  0.7258  0.0018
# Fit time          71.21   58.07   54.85   61.38   7.08
# Test time         2.58    3.08    0.82    2.16    0.97
# {'test_rmse': array([0.91513931, 0.91992049, 0.9205576 ]),
#  'test_mae': array([0.72390717, 0.72530278, 0.72828191]),
#  'fit_time': (71.21115684509277, 58.07243514060974, 54.84719777107239),
#  'test_time': (2.5757861137390137, 3.0809407234191895, 0.8213958740234375)}

# %%
predictions = algo.test(testset)

accuracy.rmse(predictions)
# Out:
# RMSE: 0.7275
# 0.7275058692357854

# %%
predictions
# Out:
# [Prediction(uid='695', iid='313', r_ui=2.0, est=2.8795105597703667, details={'was_impossible': False}),
#  Prediction(uid='177', iid='96', r_ui=3.0, est=3.7690651444091765, details={'was_impossible': False}),
#  Prediction(uid='301', iid='67', r_ui=2.0, est=3.3914121038054805, details={'was_impossible': False}),
#  Prediction(uid='867', iid='257', r_ui=4.0, est=4.11060646137873, details={'was_impossible': False}),
#  Prediction(uid='145', iid='176', r_ui=5.0, est=4.193793647675448, details={'was_impossible': False}),
#  Prediction(uid='207', iid='203', r_ui=3.0, est=3.219610105686778, details={'was_impossible': False}),
#  Prediction(uid='104', iid='268', r_ui=3.0, est=3.1207051655454285, details={'was_impossible': False}),
#  Prediction(uid='64', iid='746', r_ui=5.0, est=3.7810094014555453, details={'was_impossible': False}),
#  Prediction(uid='782', iid='989', r_ui=3.0, est=2.804569550415154, details={'was_impossible': False}),
#  Prediction(uid='184', iid='1167', r_ui=5.0, est=3.3724741310503377, details={'was_impossible': False}),
#  Prediction(uid='134', iid='338', r_ui=4.0, est=3.678003782511083, details={'was_impossible': False}),
#  Prediction(uid='42', iid='934', r_ui=4.0, est=3.461725504280151, details={'was_impossible': False}),
#  Prediction(uid='886', iid='721', r_ui=5.0, est=3.7506010942045878, details={'was_impossible': False}),
#  Prediction(uid='832', iid='258', r_ui=3.0, est=3.254434189243671, details={'was_impossible': False}),
#  Prediction(uid='934', iid='414', r_ui=5.0, est=3.8179641696888944, details={'was_impossible': False}),
#  Prediction(uid='297', iid='736', r_ui=4.0, est=3.6868330840271213, details={'was_impossible': False}),
#  Prediction(uid='551', iid='411', r_ui=1.0, est=2.723034792674777, details={'was_impossible': False}),
#  Prediction(uid='251', iid='258', r_ui=3.0, est=4.005796445367262, details={'was_impossible': False}),
#  Prediction(uid='188', iid='678', r_ui=3.0, est=3.015412524694816, details={'was_impossible': False}),
#  Prediction(uid='854', iid='126', r_ui=3.0, est=3.1588356586734063, details={'was_impossible': False}),
#  Prediction(uid='870', iid='792', r_ui=3.0, est=3.42278609231158, details={'was_impossible': False}),
#  Prediction(uid='840', iid='657', r_ui=5.0, est=4.497344283175547, details={'was_impossible': False}),
#  Prediction(uid='450', iid='1303', r_ui=4.0, est=3.2208419315991286, details={'was_impossible': False}),
#  Prediction(uid='312', iid='223', r_ui=5.0, est=4.587435458497528, details={'was_impossible': False}),
#  Prediction(uid='932', iid='616', r_ui=5.0, est=4.0360812320544, details={'was_impossible': False}),
#  Prediction(uid='533', iid='229', r_ui=4.0, est=3.479957152925202, details={'was_impossible': False}),
#  Prediction(uid='111', iid='321', r_ui=3.0, est=3.0185733479793058, details={'was_impossible': False}),
#  Prediction(uid='84', iid='1033', r_ui=4.0, est=3.431269416577472, details={'was_impossible': False}),
#  Prediction(uid='151', iid='185', r_ui=4.0, est=4.412232040370971, details={'was_impossible': False}),
#  Prediction(uid='653', iid='225', r_ui=1.0, est=2.4175994233164637, details={'was_impossible': False}),
#  Prediction(uid='751', iid='168', r_ui=5.0, est=4.031104688518431, details={'was_impossible': False}),
#  Prediction(uid='403', iid='129', r_ui=4.0, est=4.177386461691291, details={'was_impossible': False}),
#  Prediction(uid='213', iid='924', r_ui=4.0, est=3.789994464331301, details={'was_impossible': False}),
#  Prediction(uid='269', iid='157', r_ui=3.0, est=3.068321670305177, details={'was_impossible': False}),
#  Prediction(uid='524', iid='301', r_ui=4.0, est=3.4628926198032155, details={'was_impossible': False}),
#  Prediction(uid='625', iid='202', r_ui=3.0, est=3.3817174736026345, details={'was_impossible': False}),
#  Prediction(uid='198', iid='65', r_ui=2.0, est=2.877827904791428, details={'was_impossible': False}),
#  Prediction(uid='508', iid='502', r_ui=4.0, est=3.881539323627344, details={'was_impossible': False}),
#  Prediction(uid='312', iid='124', r_ui=3.0, est=4.76459482827315, details={'was_impossible': False}),
#  Prediction(uid='773', iid='90', r_ui=4.0, est=2.8958005033313134, details={'was_impossible': False}),
#  Prediction(uid='710', iid='282', r_ui=2.0, est=3.127729736376403, details={'was_impossible': False}),
#  Prediction(uid='773', iid='260', r_ui=2.0, est=2.419051857972173, details={'was_impossible': False}),
#  Prediction(uid='892', iid='582', r_ui=3.0, est=3.6137858907760467, details={'was_impossible': False}),
#  Prediction(uid='660', iid='748', r_ui=3.0, est=2.471911727301757, details={'was_impossible': False}),
#  Prediction(uid='149', iid='302', r_ui=4.0, est=3.942050133921726, details={'was_impossible': False}),
#  Prediction(uid='833', iid='431', r_ui=2.0, est=2.62332385826849, details={'was_impossible': False}),
#  Prediction(uid='807', iid='969', r_ui=4.0, est=3.9150981946935555, details={'was_impossible': False}),
#  Prediction(uid='405', iid='661', r_ui=3.0, est=2.8436587417179497, details={'was_impossible': False}),
#  Prediction(uid='340', iid='520', r_ui=5.0, est=4.592496933305782, details={'was_impossible': False}),
#  Prediction(uid='144', iid='461', r_ui=4.0, est=3.7789458163551037, details={'was_impossible': False}),
#  Prediction(uid='561', iid='959', r_ui=3.0, est=2.999305326424175, details={'was_impossible': False}),
#  Prediction(uid='312', iid='205', r_ui=5.0, est=4.579286118892242, details={'was_impossible': False}),
#  Prediction(uid='293', iid='85', r_ui=3.0, est=2.721223204337936, details={'was_impossible': False}),
#  Prediction(uid='757', iid='101', r_ui=4.0, est=3.5556297230745737, details={'was_impossible': False}),
#  Prediction(uid='236', iid='596', r_ui=4.0, est=3.8020737204283774, details={'was_impossible': False}),
#  Prediction(uid='725', iid='328', r_ui=4.0, est=3.849857307456841, details={'was_impossible': False}),
#  Prediction(uid='305', iid='428', r_ui=3.0, est=3.7426696326217943, details={'was_impossible': False}),
#  Prediction(uid='854', iid='528', r_ui=4.0, est=3.7047290927053123, details={'was_impossible': False}),
#  Prediction(uid='393', iid='420', r_ui=3.0, est=3.455974188001621, details={'was_impossible': False}),
#  Prediction(uid='533', iid='380', r_ui=4.0, est=3.725282581537696, details={'was_impossible': False}),
#  Prediction(uid='49', iid='299', r_ui=2.0, est=2.3660996870521904, details={'was_impossible': False}),
#  Prediction(uid='199', iid='473', r_ui=4.0, est=3.153412832892148, details={'was_impossible': False}),
#  Prediction(uid='627', iid='300', r_ui=4.0, est=3.7248085478189665, details={'was_impossible': False}),
#  Prediction(uid='387', iid='4', r_ui=3.0, est=3.227732553578586, details={'was_impossible': False}),
#  Prediction(uid='943', iid='98', r_ui=5.0, est=4.337300586666261, details={'was_impossible': False}),
#  Prediction(uid='655', iid='674', r_ui=3.0, est=2.6580104469951813, details={'was_impossible': False}),
#  Prediction(uid='606', iid='473', r_ui=4.0, est=3.274710012876093, details={'was_impossible': False}),
#  Prediction(uid='314', iid='410', r_ui=5.0, est=3.3167642355650737, details={'was_impossible': False}),
#  Prediction(uid='880', iid='585', r_ui=1.0, est=2.1976651657686386, details={'was_impossible': False}),
#  Prediction(uid='566', iid='423', r_ui=2.0, est=3.236681069922671, details={'was_impossible': False}),
#  Prediction(uid='891', iid='405', r_ui=3.0, est=4.031618793748831, details={'was_impossible': False}),
#  Prediction(uid='648', iid='748', r_ui=3.0, est=3.270707890035831, details={'was_impossible': False}),
#  Prediction(uid='770', iid='410', r_ui=4.0, est=3.8758306898087325, details={'was_impossible': False}),
#  Prediction(uid='672', iid='225', r_ui=2.0, est=2.294362578795435, details={'was_impossible': False}),
#  Prediction(uid='768', iid='591', r_ui=4.0, est=3.09917999594373, details={'was_impossible': False}),
#  Prediction(uid='655', iid='574', r_ui=2.0, est=1.8420310035702805, details={'was_impossible': False}),
#  Prediction(uid='622', iid='795', r_ui=2.0, est=2.1194732907827403, details={'was_impossible': False}),
#  Prediction(uid='135', iid='939', r_ui=4.0, est=3.48136618510945, details={'was_impossible': False}),
#  Prediction(uid='495', iid='1263', r_ui=4.0, est=3.5334701728356697, details={'was_impossible': False}),
#  Prediction(uid='484', iid='449', r_ui=4.0, est=3.55774523086803, details={'was_impossible': False}),
#  Prediction(uid='728', iid='319', r_ui=3.0, est=3.304939577044167, details={'was_impossible': False}),
#  Prediction(uid='109', iid='28', r_ui=3.0, est=4.214679425448304, details={'was_impossible': False}),
#  Prediction(uid='905', iid='294', r_ui=3.0, est=2.929720835933336, details={'was_impossible': False}),
#  Prediction(uid='256', iid='38', r_ui=4.0, est=3.8540339615584203, details={'was_impossible': False}),
#  Prediction(uid='426', iid='318', r_ui=5.0, est=4.3581555119830835, details={'was_impossible': False}),
#  Prediction(uid='93', iid='118', r_ui=3.0, est=3.3110167609271173, details={'was_impossible': False}),
#  Prediction(uid='551', iid='192', r_ui=5.0, est=4.561262920122662, details={'was_impossible': False}),
#  Prediction(uid='83', iid='751', r_ui=3.0, est=3.4404904328000736, details={'was_impossible': False}),
#  Prediction(uid='561', iid='1069', r_ui=4.0, est=3.217299494685588, details={'was_impossible': False}),
#  Prediction(uid='931', iid='304', r_ui=4.0, est=3.7136058885579066, details={'was_impossible': False}),
#  Prediction(uid='697', iid='245', r_ui=3.0, est=3.378541234721262, details={'was_impossible': False}),
#  Prediction(uid='643', iid='519', r_ui=4.0, est=4.236268145413036, details={'was_impossible': False}),
#  Prediction(uid='72', iid='187', r_ui=4.0, est=4.311096995770296, details={'was_impossible': False}),
#  Prediction(uid='823', iid='125', r_ui=4.0, est=3.556900454521974, details={'was_impossible': False}),
#  Prediction(uid='405', iid='83', r_ui=1.0, est=2.639173581523396, details={'was_impossible': False}),
#  Prediction(uid='545', iid='95', r_ui=4.0, est=3.7103644516956695, details={'was_impossible': False}),
#  Prediction(uid='916', iid='597', r_ui=2.0, est=2.603892646404408, details={'was_impossible': False}),
#  Prediction(uid='551', iid='458', r_ui=2.0, est=3.083185552010633, details={'was_impossible': False}),
#  Prediction(uid='74', iid='328', r_ui=4.0, est=3.6585860902683143, details={'was_impossible': False}),
#  Prediction(uid='848', iid='133', r_ui=4.0, est=4.268413039662605, details={'was_impossible': False}),
#  Prediction(uid='255', iid='859', r_ui=3.0, est=2.989123017239732, details={'was_impossible': False}),
#  Prediction(uid='59', iid='143', r_ui=1.0, est=3.370609183198513, details={'was_impossible': False}),
#  Prediction(uid='664', iid='306', r_ui=4.0, est=3.9657796991303007, details={'was_impossible': False}),
#  Prediction(uid='616', iid='288', r_ui=4.0, est=3.600971579420185, details={'was_impossible': False}),
#  Prediction(uid='686', iid='603', r_ui=5.0, est=4.899862331856383, details={'was_impossible': False}),
#  Prediction(uid='370', iid='12', r_ui=4.0, est=3.8533022973102753, details={'was_impossible': False}),
#  Prediction(uid='194', iid='1411', r_ui=1.0, est=1.806470869629526, details={'was_impossible': False}),
#  Prediction(uid='296', iid='22', r_ui=4.0, est=4.1761599535104486, details={'was_impossible': False}),
#  Prediction(uid='13', iid='692', r_ui=4.0, est=3.3384767878551074, details={'was_impossible': False}),
#  Prediction(uid='457', iid='228', r_ui=5.0, est=4.473261404466306, details={'was_impossible': False}),
#  Prediction(uid='125', iid='64', r_ui=5.0, est=4.511398021593794, details={'was_impossible': False}),
#  Prediction(uid='802', iid='424', r_ui=2.0, est=2.2247037769481013, details={'was_impossible': False}),
#  Prediction(uid='564', iid='245', r_ui=4.0, est=3.1033570154800914, details={'was_impossible': False}),
#  Prediction(uid='602', iid='127', r_ui=5.0, est=4.641031333858593, details={'was_impossible': False}),
#  Prediction(uid='807', iid='94', r_ui=2.0, est=3.296705942148705, details={'was_impossible': False}),
#  Prediction(uid='391', iid='58', r_ui=4.0, est=3.585972471127916, details={'was_impossible': False}),
#  Prediction(uid='207', iid='580', r_ui=3.0, est=2.811838222905243, details={'was_impossible': False}),
#  Prediction(uid='416', iid='660', r_ui=5.0, est=4.564946247433088, details={'was_impossible': False}),
#  Prediction(uid='264', iid='683', r_ui=2.0, est=2.8390086685882316, details={'was_impossible': False}),
#  Prediction(uid='297', iid='479', r_ui=5.0, est=4.086571953444585, details={'was_impossible': False}),
#  Prediction(uid='265', iid='327', r_ui=3.0, est=3.321349872550491, details={'was_impossible': False}),
#  Prediction(uid='682', iid='108', r_ui=3.0, est=2.653028114045487, details={'was_impossible': False}),
#  Prediction(uid='673', iid='340', r_ui=5.0, est=4.255311103084059, details={'was_impossible': False}),
#  Prediction(uid='804', iid='1016', r_ui=4.0, est=3.9360310551203574, details={'was_impossible': False}),
#  Prediction(uid='534', iid='125', r_ui=3.0, est=3.6929828447986983, details={'was_impossible': False}),
#  Prediction(uid='86', iid='286', r_ui=3.0, est=3.2102166426844594, details={'was_impossible': False}),
#  Prediction(uid='198', iid='382', r_ui=4.0, est=3.3588929822918963, details={'was_impossible': False}),
#  Prediction(uid='596', iid='181', r_ui=4.0, est=4.181285825490047, details={'was_impossible': False}),
#  Prediction(uid='897', iid='472', r_ui=5.0, est=3.9015048556079774, details={'was_impossible': False}),
#  Prediction(uid='503', iid='216', r_ui=5.0, est=4.228512457834531, details={'was_impossible': False}),
#  Prediction(uid='532', iid='369', r_ui=3.0, est=3.3561753639565803, details={'was_impossible': False}),
#  Prediction(uid='195', iid='982', r_ui=2.0, est=2.458061046071497, details={'was_impossible': False}),
#  Prediction(uid='452', iid='520', r_ui=3.0, est=3.6976012856443985, details={'was_impossible': False}),
#  Prediction(uid='916', iid='237', r_ui=3.0, est=3.377165140439009, details={'was_impossible': False}),
#  Prediction(uid='334', iid='183', r_ui=4.0, est=4.154739075846749, details={'was_impossible': False}),
#  Prediction(uid='757', iid='58', r_ui=3.0, est=3.540518922888384, details={'was_impossible': False}),
#  Prediction(uid='429', iid='137', r_ui=5.0, est=4.163564065085271, details={'was_impossible': False}),
#  Prediction(uid='885', iid='117', r_ui=4.0, est=3.6922552237692967, details={'was_impossible': False}),
#  Prediction(uid='860', iid='347', r_ui=4.0, est=3.5444830506840983, details={'was_impossible': False}),
#  Prediction(uid='608', iid='699', r_ui=5.0, est=3.9070040193586246, details={'was_impossible': False}),
#  Prediction(uid='724', iid='310', r_ui=5.0, est=3.886607089459557, details={'was_impossible': False}),
#  Prediction(uid='385', iid='487', r_ui=4.0, est=3.711009405893277, details={'was_impossible': False}),
#  Prediction(uid='92', iid='241', r_ui=3.0, est=3.259341182540966, details={'was_impossible': False}),
#  Prediction(uid='222', iid='468', r_ui=2.0, est=3.174210472610648, details={'was_impossible': False}),
#  Prediction(uid='405', iid='1468', r_ui=1.0, est=1.4094824579918968, details={'was_impossible': False}),
#  Prediction(uid='308', iid='124', r_ui=4.0, est=4.145352086183066, details={'was_impossible': False}),
#  Prediction(uid='894', iid='1281', r_ui=3.0, est=3.28142449643962, details={'was_impossible': False}),
#  Prediction(uid='305', iid='557', r_ui=4.0, est=3.5673713755728405, details={'was_impossible': False}),
#  Prediction(uid='882', iid='546', r_ui=2.0, est=3.233741461164485, details={'was_impossible': False}),
#  Prediction(uid='922', iid='15', r_ui=4.0, est=3.6729292669026643, details={'was_impossible': False}),
#  Prediction(uid='666', iid='489', r_ui=4.0, est=4.058655264092772, details={'was_impossible': False}),
#  Prediction(uid='289', iid='926', r_ui=3.0, est=2.8350244156077773, details={'was_impossible': False}),
#  Prediction(uid='524', iid='709', r_ui=5.0, est=3.8676881756960624, details={'was_impossible': False}),
#  Prediction(uid='224', iid='54', r_ui=3.0, est=3.1830635632401876, details={'was_impossible': False}),
#  Prediction(uid='450', iid='657', r_ui=4.0, est=4.55583378782452, details={'was_impossible': False}),
#  Prediction(uid='527', iid='640', r_ui=4.0, est=3.7394982273653876, details={'was_impossible': False}),
#  Prediction(uid='617', iid='396', r_ui=1.0, est=1.651800639326872, details={'was_impossible': False}),
#  Prediction(uid='324', iid='288', r_ui=5.0, est=4.64977850908329, details={'was_impossible': False}),
#  Prediction(uid='712', iid='69', r_ui=3.0, est=4.025111494329815, details={'was_impossible': False}),
#  Prediction(uid='709', iid='234', r_ui=5.0, est=3.643091664546484, details={'was_impossible': False}),
#  Prediction(uid='688', iid='309', r_ui=5.0, est=4.95243188467377, details={'was_impossible': False}),
#  Prediction(uid='834', iid='275', r_ui=3.0, est=3.76004939986677, details={'was_impossible': False}),
#  Prediction(uid='308', iid='504', r_ui=4.0, est=3.820188971437374, details={'was_impossible': False}),
#  Prediction(uid='233', iid='57', r_ui=5.0, est=4.591316972359375, details={'was_impossible': False}),
#  Prediction(uid='269', iid='521', r_ui=4.0, est=3.6612379291745816, details={'was_impossible': False}),
#  Prediction(uid='747', iid='265', r_ui=4.0, est=3.898927052047141, details={'was_impossible': False}),
#  Prediction(uid='863', iid='1607', r_ui=2.0, est=2.3318467923781734, details={'was_impossible': False}),
#  Prediction(uid='128', iid='340', r_ui=4.0, est=3.5196044003546127, details={'was_impossible': False}),
#  Prediction(uid='936', iid='866', r_ui=2.0, est=2.759082418264006, details={'was_impossible': False}),
#  Prediction(uid='299', iid='345', r_ui=4.0, est=3.7138878025366533, details={'was_impossible': False}),
#  Prediction(uid='283', iid='407', r_ui=3.0, est=3.3469839944686437, details={'was_impossible': False}),
#  Prediction(uid='671', iid='11', r_ui=4.0, est=3.5380905466174695, details={'was_impossible': False}),
#  Prediction(uid='125', iid='1270', r_ui=3.0, est=2.904141766111386, details={'was_impossible': False}),
#  Prediction(uid='96', iid='8', r_ui=5.0, est=4.31495861911778, details={'was_impossible': False}),
#  Prediction(uid='561', iid='302', r_ui=4.0, est=3.6267459286196964, details={'was_impossible': False}),
#  Prediction(uid='296', iid='181', r_ui=5.0, est=4.114029750016547, details={'was_impossible': False}),
#  Prediction(uid='804', iid='428', r_ui=3.0, est=3.933578562988935, details={'was_impossible': False}),
#  Prediction(uid='144', iid='127', r_ui=4.0, est=4.349202269481735, details={'was_impossible': False}),
#  Prediction(uid='497', iid='187', r_ui=5.0, est=4.01940231983902, details={'was_impossible': False}),
#  Prediction(uid='109', iid='8', r_ui=3.0, est=3.7189051623012683, details={'was_impossible': False}),
#  Prediction(uid='655', iid='317', r_ui=3.0, est=3.3586371964368813, details={'was_impossible': False}),
#  Prediction(uid='387', iid='381', r_ui=4.0, est=3.7372115697513237, details={'was_impossible': False}),
#  Prediction(uid='177', iid='919', r_ui=4.0, est=3.9185041390707656, details={'was_impossible': False}),
#  Prediction(uid='322', iid='514', r_ui=4.0, est=3.9494138253861464, details={'was_impossible': False}),
#  Prediction(uid='283', iid='732', r_ui=4.0, est=4.017477525841946, details={'was_impossible': False}),
#  Prediction(uid='1', iid='257', r_ui=4.0, est=3.834005403432753, details={'was_impossible': False}),
#  Prediction(uid='642', iid='165', r_ui=4.0, est=4.370523935614198, details={'was_impossible': False}),
#  Prediction(uid='693', iid='423', r_ui=3.0, est=3.193132596424239, details={'was_impossible': False}),
#  Prediction(uid='336', iid='117', r_ui=3.0, est=3.4166655846932215, details={'was_impossible': False}),
#  Prediction(uid='328', iid='550', r_ui=3.0, est=3.278750736497725, details={'was_impossible': False}),
#  Prediction(uid='541', iid='1084', r_ui=4.0, est=4.140568230589069, details={'was_impossible': False}),
#  Prediction(uid='931', iid='181', r_ui=4.0, est=3.986650196908064, details={'was_impossible': False}),
#  Prediction(uid='79', iid='290', r_ui=3.0, est=3.1408969525498716, details={'was_impossible': False}),
#  Prediction(uid='889', iid='7', r_ui=3.0, est=3.534539654067482, details={'was_impossible': False}),
#  Prediction(uid='619', iid='39', r_ui=2.0, est=2.91606059554202, details={'was_impossible': False}),
#  Prediction(uid='339', iid='498', r_ui=4.0, est=4.377585950023507, details={'was_impossible': False}),
#  Prediction(uid='932', iid='805', r_ui=4.0, est=3.6786403352136277, details={'was_impossible': False}),
#  Prediction(uid='548', iid='293', r_ui=4.0, est=4.141561451765079, details={'was_impossible': False}),
#  Prediction(uid='677', iid='91', r_ui=5.0, est=4.340455540197627, details={'was_impossible': False}),
#  Prediction(uid='360', iid='735', r_ui=5.0, est=3.9297536382918707, details={'was_impossible': False}),
#  Prediction(uid='547', iid='302', r_ui=5.0, est=3.9648850329227012, details={'was_impossible': False}),
#  Prediction(uid='234', iid='165', r_ui=5.0, est=3.878168829272462, details={'was_impossible': False}),
#  Prediction(uid='459', iid='328', r_ui=3.0, est=3.5179100168859327, details={'was_impossible': False}),
#  Prediction(uid='868', iid='191', r_ui=3.0, est=3.6020761967124426, details={'was_impossible': False}),
#  Prediction(uid='447', iid='1142', r_ui=5.0, est=4.515662959460016, details={'was_impossible': False}),
#  Prediction(uid='426', iid='289', r_ui=2.0, est=3.060640349367527, details={'was_impossible': False}),
#  Prediction(uid='912', iid='655', r_ui=5.0, est=4.005454196971884, details={'was_impossible': False}),
#  Prediction(uid='303', iid='654', r_ui=5.0, est=4.349230419131322, details={'was_impossible': False}),
#  Prediction(uid='405', iid='670', r_ui=1.0, est=1.7211754925863816, details={'was_impossible': False}),
#  Prediction(uid='868', iid='176', r_ui=4.0, est=3.6745758096772856, details={'was_impossible': False}),
#  Prediction(uid='276', iid='67', r_ui=3.0, est=3.4116507945925014, details={'was_impossible': False}),
#  Prediction(uid='64', iid='516', r_ui=5.0, est=4.135820762822011, details={'was_impossible': False}),
#  Prediction(uid='269', iid='15', r_ui=2.0, est=2.41363382157472, details={'was_impossible': False}),
#  Prediction(uid='230', iid='291', r_ui=4.0, est=3.2720238336359566, details={'was_impossible': False}),
#  Prediction(uid='920', iid='302', r_ui=4.0, est=3.7616953095741654, details={'was_impossible': False}),
#  Prediction(uid='447', iid='117', r_ui=4.0, est=3.5848297128992628, details={'was_impossible': False}),
#  Prediction(uid='674', iid='300', r_ui=3.0, est=3.635946522282085, details={'was_impossible': False}),
#  Prediction(uid='373', iid='28', r_ui=3.0, est=3.921223060834661, details={'was_impossible': False}),
#  Prediction(uid='862', iid='496', r_ui=5.0, est=4.601219758483185, details={'was_impossible': False}),
#  Prediction(uid='416', iid='157', r_ui=4.0, est=3.899199157199846, details={'was_impossible': False}),
#  Prediction(uid='333', iid='316', r_ui=5.0, est=4.592339668442656, details={'was_impossible': False}),
#  Prediction(uid='437', iid='418', r_ui=3.0, est=3.4760874634070262, details={'was_impossible': False}),
#  Prediction(uid='346', iid='187', r_ui=3.0, est=3.7181724120306154, details={'was_impossible': False}),
#  Prediction(uid='918', iid='640', r_ui=3.0, est=2.7901028561187298, details={'was_impossible': False}),
#  Prediction(uid='643', iid='65', r_ui=4.0, est=3.5480134747237426, details={'was_impossible': False}),
#  Prediction(uid='615', iid='275', r_ui=4.0, est=4.131220095986706, details={'was_impossible': False}),
#  Prediction(uid='207', iid='313', r_ui=4.0, est=3.961009493584859, details={'was_impossible': False}),
#  Prediction(uid='94', iid='710', r_ui=3.0, est=3.5486230822878815, details={'was_impossible': False}),
#  Prediction(uid='565', iid='30', r_ui=5.0, est=4.866981607249015, details={'was_impossible': False}),
#  Prediction(uid='312', iid='521', r_ui=5.0, est=4.38194418270771, details={'was_impossible': False}),
#  Prediction(uid='239', iid='427', r_ui=5.0, est=4.361076627028429, details={'was_impossible': False}),
#  Prediction(uid='276', iid='27', r_ui=3.0, est=2.9707369828869568, details={'was_impossible': False}),
#  Prediction(uid='648', iid='152', r_ui=5.0, est=4.194002019093879, details={'was_impossible': False}),
#  Prediction(uid='807', iid='258', r_ui=3.0, est=3.7337831685050054, details={'was_impossible': False}),
#  Prediction(uid='81', iid='619', r_ui=3.0, est=3.1600125800912897, details={'was_impossible': False}),
#  Prediction(uid='201', iid='387', r_ui=2.0, est=2.6023895996041997, details={'was_impossible': False}),
#  Prediction(uid='694', iid='385', r_ui=4.0, est=3.8881671787711003, details={'was_impossible': False}),
#  Prediction(uid='759', iid='220', r_ui=5.0, est=3.6369248591315766, details={'was_impossible': False}),
#  Prediction(uid='508', iid='1067', r_ui=4.0, est=3.784661762256585, details={'was_impossible': False}),
#  Prediction(uid='201', iid='695', r_ui=1.0, est=1.6883161341622843, details={'was_impossible': False}),
#  Prediction(uid='387', iid='441', r_ui=1.0, est=2.0069804880224527, details={'was_impossible': False}),
#  Prediction(uid='250', iid='477', r_ui=3.0, est=3.3244737662488846, details={'was_impossible': False}),
#  Prediction(uid='316', iid='582', r_ui=5.0, est=4.59554069537715, details={'was_impossible': False}),
#  Prediction(uid='807', iid='503', r_ui=3.0, est=3.560445598775456, details={'was_impossible': False}),
#  Prediction(uid='860', iid='316', r_ui=3.0, est=3.945884983011222, details={'was_impossible': False}),
#  Prediction(uid='938', iid='676', r_ui=3.0, est=3.0746152546541383, details={'was_impossible': False}),
#  Prediction(uid='543', iid='117', r_ui=3.0, est=3.3607239529008206, details={'was_impossible': False}),
#  Prediction(uid='474', iid='294', r_ui=3.0, est=3.280992905451583, details={'was_impossible': False}),
#  Prediction(uid='85', iid='269', r_ui=3.0, est=3.740136251577001, details={'was_impossible': False}),
#  Prediction(uid='92', iid='708', r_ui=4.0, est=3.5498875509424175, details={'was_impossible': False}),
#  Prediction(uid='409', iid='1020', r_ui=5.0, est=3.557064014748845, details={'was_impossible': False}),
#  Prediction(uid='429', iid='786', r_ui=2.0, est=2.6939770176158158, details={'was_impossible': False}),
#  Prediction(uid='833', iid='980', r_ui=3.0, est=2.9710806601569852, details={'was_impossible': False}),
#  Prediction(uid='453', iid='4', r_ui=4.0, est=3.658187377315817, details={'was_impossible': False}),
#  Prediction(uid='733', iid='459', r_ui=4.0, est=3.350612449148833, details={'was_impossible': False}),
#  Prediction(uid='7', iid='658', r_ui=3.0, est=3.816035347557055, details={'was_impossible': False}),
#  Prediction(uid='378', iid='1523', r_ui=2.0, est=3.632082231966077, details={'was_impossible': False}),
#  Prediction(uid='429', iid='229', r_ui=2.0, est=2.881157348924446, details={'was_impossible': False}),
#  Prediction(uid='735', iid='181', r_ui=4.0, est=3.724666513526844, details={'was_impossible': False}),
#  Prediction(uid='669', iid='235', r_ui=2.0, est=2.083665848671246, details={'was_impossible': False}),
#  Prediction(uid='7', iid='324', r_ui=1.0, est=3.5276578443354953, details={'was_impossible': False}),
#  Prediction(uid='405', iid='1592', r_ui=1.0, est=1.3282166784661964, details={'was_impossible': False}),
#  Prediction(uid='297', iid='181', r_ui=4.0, est=3.616855226262102, details={'was_impossible': False}),
#  Prediction(uid='504', iid='505', r_ui=4.0, est=4.061664485377114, details={'was_impossible': False}),
#  Prediction(uid='405', iid='1311', r_ui=1.0, est=1.0289948629260857, details={'was_impossible': False}),
#  Prediction(uid='500', iid='211', r_ui=3.0, est=3.7650196434100125, details={'was_impossible': False}),
#  Prediction(uid='151', iid='602', r_ui=4.0, est=3.8514793731413577, details={'was_impossible': False}),
#  Prediction(uid='918', iid='485', r_ui=3.0, est=3.362051581985246, details={'was_impossible': False}),
#  Prediction(uid='554', iid='275', r_ui=4.0, est=3.848812707576043, details={'was_impossible': False}),
#  Prediction(uid='495', iid='183', r_ui=5.0, est=4.758318119021304, details={'was_impossible': False}),
#  Prediction(uid='244', iid='100', r_ui=4.0, est=4.369456949460832, details={'was_impossible': False}),
#  Prediction(uid='330', iid='470', r_ui=5.0, est=4.663892730224913, details={'was_impossible': False}),
#  Prediction(uid='495', iid='479', r_ui=4.0, est=4.535886328146712, details={'was_impossible': False}),
#  Prediction(uid='934', iid='516', r_ui=3.0, est=3.508506833010104, details={'was_impossible': False}),
#  Prediction(uid='267', iid='685', r_ui=3.0, est=3.510574332377741, details={'was_impossible': False}),
#  Prediction(uid='184', iid='40', r_ui=4.0, est=3.1846734069414357, details={'was_impossible': False}),
#  Prediction(uid='940', iid='98', r_ui=4.0, est=3.9136818741292556, details={'was_impossible': False}),
#  Prediction(uid='805', iid='597', r_ui=3.0, est=2.8274596163058385, details={'was_impossible': False}),
#  Prediction(uid='773', iid='153', r_ui=5.0, est=3.8280923933001363, details={'was_impossible': False}),
#  Prediction(uid='79', iid='340', r_ui=4.0, est=3.8041223231437704, details={'was_impossible': False}),
#  Prediction(uid='782', iid='994', r_ui=2.0, est=2.3782254694211518, details={'was_impossible': False}),
#  Prediction(uid='666', iid='502', r_ui=3.0, est=3.565534643544435, details={'was_impossible': False}),
#  Prediction(uid='754', iid='276', r_ui=5.0, est=4.0717182997370065, details={'was_impossible': False}),
#  Prediction(uid='269', iid='739', r_ui=1.0, est=1.5367422749742081, details={'was_impossible': False}),
#  Prediction(uid='811', iid='988', r_ui=4.0, est=3.6614009836406374, details={'was_impossible': False}),
#  Prediction(uid='913', iid='12', r_ui=4.0, est=4.269300674623932, details={'was_impossible': False}),
#  Prediction(uid='7', iid='56', r_ui=5.0, est=4.611461872302994, details={'was_impossible': False}),
#  Prediction(uid='328', iid='540', r_ui=3.0, est=2.726585398633047, details={'was_impossible': False}),
#  Prediction(uid='514', iid='177', r_ui=3.0, est=3.564609595012159, details={'was_impossible': False}),
#  Prediction(uid='704', iid='486', r_ui=4.0, est=3.8554885190233095, details={'was_impossible': False}),
#  Prediction(uid='821', iid='1', r_ui=5.0, est=4.6269647866450985, details={'was_impossible': False}),
#  Prediction(uid='143', iid='315', r_ui=4.0, est=4.166065875013966, details={'was_impossible': False}),
#  Prediction(uid='650', iid='1110', r_ui=4.0, est=2.9605876910559576, details={'was_impossible': False}),
#  Prediction(uid='489', iid='319', r_ui=3.0, est=3.4719848993006646, details={'was_impossible': False}),
#  Prediction(uid='440', iid='324', r_ui=5.0, est=3.3397894549838143, details={'was_impossible': False}),
#  Prediction(uid='686', iid='299', r_ui=5.0, est=3.8985603357153638, details={'was_impossible': False}),
#  Prediction(uid='398', iid='589', r_ui=3.0, est=3.6369936726453176, details={'was_impossible': False}),
#  Prediction(uid='208', iid='430', r_ui=4.0, est=3.738889311342777, details={'was_impossible': False}),
#  Prediction(uid='399', iid='710', r_ui=2.0, est=3.283749044837119, details={'was_impossible': False}),
#  Prediction(uid='409', iid='154', r_ui=5.0, est=4.173132123615789, details={'was_impossible': False}),
#  Prediction(uid='484', iid='234', r_ui=4.0, est=4.196067749825154, details={'was_impossible': False}),
#  Prediction(uid='656', iid='340', r_ui=3.0, est=2.893455620513287, details={'was_impossible': False}),
#  Prediction(uid='487', iid='71', r_ui=3.0, est=3.98404928243287, details={'was_impossible': False}),
#  Prediction(uid='846', iid='52', r_ui=4.0, est=4.080293058390037, details={'was_impossible': False}),
#  Prediction(uid='1', iid='264', r_ui=2.0, est=2.5236462302861216, details={'was_impossible': False}),
#  Prediction(uid='289', iid='21', r_ui=1.0, est=2.549503524848786, details={'was_impossible': False}),
#  Prediction(uid='142', iid='514', r_ui=5.0, est=4.643771777832419, details={'was_impossible': False}),
#  Prediction(uid='325', iid='240', r_ui=1.0, est=2.3406104016491094, details={'was_impossible': False}),
#  Prediction(uid='552', iid='866', r_ui=3.0, est=3.030859458624545, details={'was_impossible': False}),
#  Prediction(uid='299', iid='275', r_ui=4.0, est=3.7217137199889723, details={'was_impossible': False}),
#  Prediction(uid='378', iid='977', r_ui=3.0, est=2.595111005535146, details={'was_impossible': False}),
#  Prediction(uid='186', iid='356', r_ui=5.0, est=4.025962586746356, details={'was_impossible': False}),
#  Prediction(uid='863', iid='307', r_ui=5.0, est=4.042137652943053, details={'was_impossible': False}),
#  Prediction(uid='712', iid='395', r_ui=4.0, est=3.673398256600623, details={'was_impossible': False}),
#  Prediction(uid='436', iid='559', r_ui=4.0, est=3.635834422254109, details={'was_impossible': False}),
#  Prediction(uid='870', iid='317', r_ui=4.0, est=3.8251349699552217, details={'was_impossible': False}),
#  Prediction(uid='295', iid='401', r_ui=3.0, est=3.4269423133801054, details={'was_impossible': False}),
#  Prediction(uid='474', iid='966', r_ui=4.0, est=4.241434879683919, details={'was_impossible': False}),
#  Prediction(uid='645', iid='654', r_ui=5.0, est=4.670249975554783, details={'was_impossible': False}),
#  Prediction(uid='337', iid='520', r_ui=5.0, est=4.770140262471943, details={'was_impossible': False}),
#  Prediction(uid='308', iid='97', r_ui=1.0, est=3.5352357317314658, details={'was_impossible': False}),
#  Prediction(uid='297', iid='194', r_ui=3.0, est=3.841472233595268, details={'was_impossible': False}),
#  Prediction(uid='663', iid='845', r_ui=3.0, est=3.1055401112984593, details={'was_impossible': False}),
#  Prediction(uid='175', iid='12', r_ui=4.0, est=4.159051357719913, details={'was_impossible': False}),
#  Prediction(uid='682', iid='824', r_ui=1.0, est=2.307051368897992, details={'was_impossible': False}),
#  Prediction(uid='194', iid='274', r_ui=2.0, est=2.851116851161099, details={'was_impossible': False}),
#  Prediction(uid='693', iid='604', r_ui=3.0, est=3.555891337787642, details={'was_impossible': False}),
#  Prediction(uid='451', iid='882', r_ui=1.0, est=1.510345438234626, details={'was_impossible': False}),
#  Prediction(uid='243', iid='306', r_ui=4.0, est=4.099632558079064, details={'was_impossible': False}),
#  Prediction(uid='18', iid='462', r_ui=3.0, est=3.9233760209854416, details={'was_impossible': False}),
#  Prediction(uid='66', iid='248', r_ui=4.0, est=3.087516760601036, details={'was_impossible': False}),
#  Prediction(uid='334', iid='430', r_ui=4.0, est=4.058977951589338, details={'was_impossible': False}),
#  Prediction(uid='537', iid='175', r_ui=4.0, est=3.31997229397866, details={'was_impossible': False}),
#  Prediction(uid='276', iid='1145', r_ui=2.0, est=3.1959466484165113, details={'was_impossible': False}),
#  Prediction(uid='637', iid='274', r_ui=5.0, est=3.6523765303187217, details={'was_impossible': False}),
#  Prediction(uid='393', iid='1055', r_ui=4.0, est=3.41819605265766, details={'was_impossible': False}),
#  Prediction(uid='385', iid='480', r_ui=5.0, est=4.152203011246629, details={'was_impossible': False}),
#  Prediction(uid='7', iid='174', r_ui=5.0, est=4.642255485863162, details={'was_impossible': False}),
#  Prediction(uid='545', iid='208', r_ui=3.0, est=3.8877913942751476, details={'was_impossible': False}),
#  Prediction(uid='676', iid='169', r_ui=5.0, est=4.780530711265144, details={'was_impossible': False}),
#  Prediction(uid='35', iid='333', r_ui=4.0, est=3.538593516521928, details={'was_impossible': False}),
#  Prediction(uid='115', iid='79', r_ui=4.0, est=3.4727033749579506, details={'was_impossible': False}),
#  Prediction(uid='381', iid='283', r_ui=5.0, est=4.1965736341954045, details={'was_impossible': False}),
#  Prediction(uid='493', iid='959', r_ui=2.0, est=2.946580653847507, details={'was_impossible': False}),
#  Prediction(uid='660', iid='186', r_ui=3.0, est=3.0229637649136487, details={'was_impossible': False}),
#  Prediction(uid='308', iid='121', r_ui=3.0, est=3.293764051287943, details={'was_impossible': False}),
#  Prediction(uid='290', iid='318', r_ui=4.0, est=4.27474500580113, details={'was_impossible': False}),
#  Prediction(uid='562', iid='591', r_ui=4.0, est=3.4198342107272746, details={'was_impossible': False}),
#  Prediction(uid='399', iid='196', r_ui=5.0, est=3.568755094423238, details={'was_impossible': False}),
#  Prediction(uid='56', iid='426', r_ui=4.0, est=3.463755416956217, details={'was_impossible': False}),
#  Prediction(uid='32', iid='245', r_ui=2.0, est=2.6608669188680922, details={'was_impossible': False}),
#  Prediction(uid='463', iid='1284', r_ui=4.0, est=3.3421687558581827, details={'was_impossible': False}),
#  Prediction(uid='854', iid='537', r_ui=3.0, est=3.524470430419645, details={'was_impossible': False}),
#  Prediction(uid='870', iid='178', r_ui=4.0, est=4.069198486829007, details={'was_impossible': False}),
#  Prediction(uid='271', iid='435', r_ui=4.0, est=3.918761245843635, details={'was_impossible': False}),
#  Prediction(uid='661', iid='1035', r_ui=3.0, est=3.395072198859189, details={'was_impossible': False}),
#  Prediction(uid='625', iid='300', r_ui=3.0, est=3.0028065987064663, details={'was_impossible': False}),
#  Prediction(uid='715', iid='168', r_ui=4.0, est=4.039545242260976, details={'was_impossible': False}),
#  Prediction(uid='852', iid='252', r_ui=3.0, est=3.2514178573406647, details={'was_impossible': False}),
#  Prediction(uid='298', iid='474', r_ui=4.0, est=4.296413223209271, details={'was_impossible': False}),
#  Prediction(uid='930', iid='107', r_ui=3.0, est=2.841936170197645, details={'was_impossible': False}),
#  Prediction(uid='487', iid='366', r_ui=3.0, est=3.7520748116224554, details={'was_impossible': False}),
#  Prediction(uid='796', iid='326', r_ui=4.0, est=3.817882849931763, details={'was_impossible': False}),
#  Prediction(uid='409', iid='275', r_ui=4.0, est=3.8691811856193477, details={'was_impossible': False}),
#  Prediction(uid='46', iid='245', r_ui=3.0, est=3.4361105657252704, details={'was_impossible': False}),
#  Prediction(uid='234', iid='625', r_ui=3.0, est=2.8813815160571035, details={'was_impossible': False}),
#  Prediction(uid='807', iid='208', r_ui=4.0, est=4.158537658388058, details={'was_impossible': False}),
#  Prediction(uid='145', iid='348', r_ui=4.0, est=3.843569914321386, details={'was_impossible': False}),
#  Prediction(uid='447', iid='405', r_ui=2.0, est=3.2376615177480397, details={'was_impossible': False}),
#  Prediction(uid='438', iid='321', r_ui=5.0, est=4.344767438153948, details={'was_impossible': False}),
#  Prediction(uid='627', iid='586', r_ui=3.0, est=2.6432273001741726, details={'was_impossible': False}),
#  Prediction(uid='319', iid='750', r_ui=3.0, est=3.713227716624388, details={'was_impossible': False}),
#  Prediction(uid='145', iid='770', r_ui=1.0, est=2.378849263961217, details={'was_impossible': False}),
#  Prediction(uid='405', iid='226', r_ui=2.0, est=2.6969452933093616, details={'was_impossible': False}),
#  Prediction(uid='117', iid='789', r_ui=4.0, est=4.3658150061512115, details={'was_impossible': False}),
#  Prediction(uid='934', iid='177', r_ui=3.0, est=3.5787038183435653, details={'was_impossible': False}),
#  Prediction(uid='119', iid='455', r_ui=4.0, est=3.480052514711026, details={'was_impossible': False}),
#  Prediction(uid='815', iid='436', r_ui=3.0, est=3.577909906798906, details={'was_impossible': False}),
#  Prediction(uid='144', iid='9', r_ui=5.0, est=3.8881806772942644, details={'was_impossible': False}),
#  Prediction(uid='276', iid='118', r_ui=3.0, est=2.9651523765745256, details={'was_impossible': False}),
#  Prediction(uid='433', iid='690', r_ui=2.0, est=2.549860734560828, details={'was_impossible': False}),
#  Prediction(uid='49', iid='428', r_ui=5.0, est=3.5036987148624035, details={'was_impossible': False}),
#  Prediction(uid='334', iid='319', r_ui=3.0, est=3.0673095736195517, details={'was_impossible': False}),
#  Prediction(uid='321', iid='479', r_ui=4.0, est=4.0739130303176525, details={'was_impossible': False}),
#  Prediction(uid='660', iid='182', r_ui=2.0, est=2.815410279565673, details={'was_impossible': False}),
#  Prediction(uid='344', iid='516', r_ui=5.0, est=4.212256689203879, details={'was_impossible': False}),
#  Prediction(uid='490', iid='302', r_ui=4.0, est=3.995557578128392, details={'was_impossible': False}),
#  Prediction(uid='752', iid='358', r_ui=4.0, est=3.4794550671926503, details={'was_impossible': False}),
#  Prediction(uid='138', iid='116', r_ui=2.0, est=3.3234706194417463, details={'was_impossible': False}),
#  Prediction(uid='71', iid='151', r_ui=1.0, est=3.7848219176179625, details={'was_impossible': False}),
#  Prediction(uid='699', iid='989', r_ui=4.0, est=2.7641299534503476, details={'was_impossible': False}),
#  Prediction(uid='305', iid='285', r_ui=5.0, est=4.19639206690063, details={'was_impossible': False}),
#  Prediction(uid='795', iid='410', r_ui=2.0, est=2.6328281908776345, details={'was_impossible': False}),
#  Prediction(uid='783', iid='887', r_ui=5.0, est=4.497894569544579, details={'was_impossible': False}),
#  Prediction(uid='889', iid='97', r_ui=3.0, est=3.3468501807109425, details={'was_impossible': False}),
#  Prediction(uid='233', iid='70', r_ui=5.0, est=4.109216580621149, details={'was_impossible': False}),
#  Prediction(uid='840', iid='83', r_ui=5.0, est=4.097688664964296, details={'was_impossible': False}),
#  Prediction(uid='753', iid='359', r_ui=4.0, est=3.7438025803794175, details={'was_impossible': False}),
#  Prediction(uid='784', iid='307', r_ui=4.0, est=3.874604189609986, details={'was_impossible': False}),
#  Prediction(uid='601', iid='153', r_ui=4.0, est=3.490143956259777, details={'was_impossible': False}),
#  Prediction(uid='113', iid='325', r_ui=4.0, est=3.4675569220134617, details={'was_impossible': False}),
#  Prediction(uid='406', iid='444', r_ui=3.0, est=3.302199223646967, details={'was_impossible': False}),
#  Prediction(uid='387', iid='463', r_ui=4.0, est=3.9252597972404315, details={'was_impossible': False}),
#  Prediction(uid='156', iid='510', r_ui=4.0, est=3.7828565192623804, details={'was_impossible': False}),
#  Prediction(uid='89', iid='7', r_ui=5.0, est=4.454249972118608, details={'was_impossible': False}),
#  Prediction(uid='751', iid='497', r_ui=4.0, est=3.6923467916143418, details={'was_impossible': False}),
#  Prediction(uid='659', iid='601', r_ui=3.0, est=3.838394206914995, details={'was_impossible': False}),
#  Prediction(uid='639', iid='709', r_ui=3.0, est=3.2239120914708472, details={'was_impossible': False}),
#  Prediction(uid='593', iid='742', r_ui=4.0, est=3.7649084142776803, details={'was_impossible': False}),
#  Prediction(uid='541', iid='1036', r_ui=2.0, est=2.202672147763354, details={'was_impossible': False}),
#  Prediction(uid='536', iid='546', r_ui=2.0, est=2.9550603598070495, details={'was_impossible': False}),
#  Prediction(uid='417', iid='452', r_ui=2.0, est=2.6661635925715093, details={'was_impossible': False}),
#  Prediction(uid='690', iid='174', r_ui=4.0, est=3.9740076060148994, details={'was_impossible': False}),
#  Prediction(uid='514', iid='511', r_ui=3.0, est=4.029271569172263, details={'was_impossible': False}),
#  Prediction(uid='709', iid='118', r_ui=5.0, est=3.4217028567784493, details={'was_impossible': False}),
#  Prediction(uid='606', iid='827', r_ui=3.0, est=3.1833192978211, details={'was_impossible': False}),
#  Prediction(uid='836', iid='260', r_ui=2.0, est=2.3326649621971898, details={'was_impossible': False}),
#  Prediction(uid='865', iid='928', r_ui=1.0, est=1.550615881448341, details={'was_impossible': False}),
#  Prediction(uid='416', iid='1136', r_ui=4.0, est=3.8518448258874343, details={'was_impossible': False}),
#  Prediction(uid='904', iid='300', r_ui=4.0, est=3.8331882969083497, details={'was_impossible': False}),
#  Prediction(uid='84', iid='322', r_ui=3.0, est=3.175798733770909, details={'was_impossible': False}),
#  Prediction(uid='406', iid='508', r_ui=4.0, est=3.612894214837978, details={'was_impossible': False}),
#  Prediction(uid='842', iid='303', r_ui=5.0, est=4.3209492111117775, details={'was_impossible': False}),
#  Prediction(uid='728', iid='471', r_ui=4.0, est=3.71676143143033, details={'was_impossible': False}),
#  Prediction(uid='761', iid='222', r_ui=4.0, est=3.881777721709463, details={'was_impossible': False}),
#  Prediction(uid='63', iid='13', r_ui=4.0, est=3.0066156014358087, details={'was_impossible': False}),
#  Prediction(uid='543', iid='423', r_ui=3.0, est=3.5654994956554673, details={'was_impossible': False}),
#  Prediction(uid='208', iid='739', r_ui=4.0, est=3.844302572661917, details={'was_impossible': False}),
#  Prediction(uid='921', iid='196', r_ui=5.0, est=3.6758625049099045, details={'was_impossible': False}),
#  Prediction(uid='877', iid='79', r_ui=4.0, est=4.0092769333740845, details={'was_impossible': False}),
#  Prediction(uid='343', iid='66', r_ui=3.0, est=3.1813563394773956, details={'was_impossible': False}),
#  Prediction(uid='878', iid='111', r_ui=4.0, est=3.2013241704564557, details={'was_impossible': False}),
#  Prediction(uid='561', iid='1', r_ui=2.0, est=3.225803045390953, details={'was_impossible': False}),
#  Prediction(uid='297', iid='185', r_ui=5.0, est=4.0944053020298465, details={'was_impossible': False}),
#  Prediction(uid='374', iid='147', r_ui=3.0, est=3.3679385152666956, details={'was_impossible': False}),
#  Prediction(uid='533', iid='218', r_ui=2.0, est=3.1530088749592786, details={'was_impossible': False}),
#  Prediction(uid='191', iid='332', r_ui=2.0, est=3.221246078843191, details={'was_impossible': False}),
#  Prediction(uid='286', iid='819', r_ui=3.0, est=3.078598576855759, details={'was_impossible': False}),
#  Prediction(uid='87', iid='728', r_ui=4.0, est=3.5028859544157824, details={'was_impossible': False}),
#  Prediction(uid='798', iid='993', r_ui=3.0, est=3.4878928718334508, details={'was_impossible': False}),
#  Prediction(uid='293', iid='429', r_ui=4.0, est=3.5535662704888074, details={'was_impossible': False}),
#  Prediction(uid='648', iid='633', r_ui=3.0, est=3.654831966289263, details={'was_impossible': False}),
#  Prediction(uid='868', iid='227', r_ui=1.0, est=2.427024477318759, details={'was_impossible': False}),
#  Prediction(uid='788', iid='68', r_ui=3.0, est=2.918923968130861, details={'was_impossible': False}),
#  Prediction(uid='901', iid='451', r_ui=4.0, est=3.9712064864103547, details={'was_impossible': False}),
#  Prediction(uid='119', iid='274', r_ui=4.0, est=3.96363350233502, details={'was_impossible': False}),
#  Prediction(uid='117', iid='358', r_ui=4.0, est=3.296694226212942, details={'was_impossible': False}),
#  Prediction(uid='621', iid='73', r_ui=5.0, est=3.8928563947512895, details={'was_impossible': False}),
#  Prediction(uid='882', iid='4', r_ui=4.0, est=3.9937034168202143, details={'was_impossible': False}),
#  Prediction(uid='334', iid='815', r_ui=3.0, est=3.0712204818680116, details={'was_impossible': False}),
#  Prediction(uid='25', iid='657', r_ui=4.0, est=4.3957213682367575, details={'was_impossible': False}),
#  Prediction(uid='822', iid='1', r_ui=4.0, est=3.51137217462339, details={'was_impossible': False}),
#  Prediction(uid='737', iid='58', r_ui=4.0, est=3.564479625631767, details={'was_impossible': False}),
#  Prediction(uid='807', iid='186', r_ui=4.0, est=3.863222149573496, details={'was_impossible': False}),
#  Prediction(uid='23', iid='419', r_ui=3.0, est=3.555091030430001, details={'was_impossible': False}),
#  Prediction(uid='222', iid='377', r_ui=1.0, est=1.7507570500262157, details={'was_impossible': False}),
#  Prediction(uid='429', iid='479', r_ui=4.0, est=4.1695054139137975, details={'was_impossible': False}),
#  Prediction(uid='73', iid='271', r_ui=2.0, est=2.4631754097704857, details={'was_impossible': False}),
#  Prediction(uid='373', iid='1228', r_ui=2.0, est=2.715970489230551, details={'was_impossible': False}),
#  Prediction(uid='864', iid='127', r_ui=4.0, est=4.606723668556715, details={'was_impossible': False}),
#  Prediction(uid='650', iid='161', r_ui=3.0, est=2.986646647311659, details={'was_impossible': False}),
#  Prediction(uid='936', iid='3', r_ui=4.0, est=3.3893735963140172, details={'was_impossible': False}),
#  Prediction(uid='492', iid='462', r_ui=3.0, est=3.598032477810675, details={'was_impossible': False}),
#  Prediction(uid='659', iid='356', r_ui=3.0, est=3.2486220731743214, details={'was_impossible': False}),
#  Prediction(uid='201', iid='123', r_ui=2.0, est=2.7393524843261026, details={'was_impossible': False}),
# ...
#  Prediction(uid='82', iid='661', r_ui=4.0, est=3.6887943054395875, details={'was_impossible': False}),
#  Prediction(uid='468', iid='1012', r_ui=4.0, est=3.9165990267945525, details={'was_impossible': False}),
#  Prediction(uid='325', iid='114', r_ui=5.0, est=4.3076261181121795, details={'was_impossible': False}),
#  Prediction(uid='870', iid='949', r_ui=3.0, est=2.9139905234375627, details={'was_impossible': False}),
#  Prediction(uid='442', iid='96', r_ui=4.0, est=3.737147866627235, details={'was_impossible': False}),
#  Prediction(uid='405', iid='698', r_ui=1.0, est=1.3309285398798614, details={'was_impossible': False}),
#  Prediction(uid='848', iid='200', r_ui=2.0, est=3.8051805370389524, details={'was_impossible': False}),
#  Prediction(uid='916', iid='213', r_ui=4.0, est=3.8704644232569243, details={'was_impossible': False}),
#  Prediction(uid='62', iid='1129', r_ui=5.0, est=4.163148801672781, details={'was_impossible': False}),
#  Prediction(uid='177', iid='327', r_ui=3.0, est=3.7258149859064433, details={'was_impossible': False}),
#  Prediction(uid='880', iid='1188', r_ui=2.0, est=2.6641104932323274, details={'was_impossible': False}),
#  Prediction(uid='588', iid='289', r_ui=2.0, est=3.0548457230739747, details={'was_impossible': False}),
#  Prediction(uid='180', iid='216', r_ui=5.0, est=4.145413763761932, details={'was_impossible': False}),
#  Prediction(uid='673', iid='310', r_ui=5.0, est=4.213872809392585, details={'was_impossible': False}),
#  Prediction(uid='151', iid='492', r_ui=3.0, est=3.7479840649005944, details={'was_impossible': False}),
#  Prediction(uid='393', iid='323', r_ui=2.0, est=3.0430028556560855, details={'was_impossible': False}),
#  Prediction(uid='499', iid='425', r_ui=3.0, est=3.604777514966539, details={'was_impossible': False}),
#  Prediction(uid='18', iid='165', r_ui=4.0, est=4.1707293594539285, details={'was_impossible': False}),
#  Prediction(uid='354', iid='186', r_ui=4.0, est=3.6715334071916597, details={'was_impossible': False}),
#  Prediction(uid='107', iid='333', r_ui=3.0, est=3.62690420096186, details={'was_impossible': False}),
#  Prediction(uid='308', iid='629', r_ui=4.0, est=3.596127875012706, details={'was_impossible': False}),
#  Prediction(uid='392', iid='837', r_ui=5.0, est=4.542539447817822, details={'was_impossible': False}),
#  Prediction(uid='501', iid='544', r_ui=4.0, est=3.7148840877288403, details={'was_impossible': False}),
#  Prediction(uid='127', iid='300', r_ui=5.0, est=4.260932028381278, details={'was_impossible': False}),
#  Prediction(uid='619', iid='241', r_ui=5.0, est=4.190366087752137, details={'was_impossible': False}),
#  Prediction(uid='465', iid='181', r_ui=3.0, est=3.2455415174910613, details={'was_impossible': False}),
#  Prediction(uid='783', iid='294', r_ui=3.0, est=3.5792251447304344, details={'was_impossible': False}),
#  Prediction(uid='336', iid='204', r_ui=5.0, est=3.659659987644318, details={'was_impossible': False}),
#  Prediction(uid='807', iid='154', r_ui=2.0, est=3.556343435884697, details={'was_impossible': False}),
#  Prediction(uid='106', iid='64', r_ui=4.0, est=4.442781763464153, details={'was_impossible': False}),
#  Prediction(uid='862', iid='215', r_ui=4.0, est=3.9959864013787643, details={'was_impossible': False}),
#  Prediction(uid='18', iid='170', r_ui=5.0, est=4.3720904250491115, details={'was_impossible': False}),
#  Prediction(uid='574', iid='302', r_ui=4.0, est=3.9465825674815704, details={'was_impossible': False}),
#  Prediction(uid='181', iid='1379', r_ui=1.0, est=1.5761181116937217, details={'was_impossible': False}),
#  Prediction(uid='301', iid='419', r_ui=3.0, est=3.386282385466108, details={'was_impossible': False}),
#  Prediction(uid='488', iid='678', r_ui=2.0, est=2.5555118052346177, details={'was_impossible': False}),
#  Prediction(uid='308', iid='583', r_ui=4.0, est=3.19592736938611, details={'was_impossible': False}),
#  Prediction(uid='234', iid='243', r_ui=1.0, est=1.6858439447277003, details={'was_impossible': False}),
#  Prediction(uid='714', iid='9', r_ui=3.0, est=3.736937526580121, details={'was_impossible': False}),
#  Prediction(uid='532', iid='153', r_ui=4.0, est=4.446776233856657, details={'was_impossible': False}),
#  Prediction(uid='899', iid='732', r_ui=3.0, est=3.4844805773912277, details={'was_impossible': False}),
#  Prediction(uid='642', iid='364', r_ui=5.0, est=3.825066536777439, details={'was_impossible': False}),
#  Prediction(uid='450', iid='421', r_ui=4.0, est=4.16302441564566, details={'was_impossible': False}),
#  Prediction(uid='459', iid='651', r_ui=3.0, est=4.064496256280132, details={'was_impossible': False}),
#  Prediction(uid='236', iid='199', r_ui=4.0, est=3.8666976716501114, details={'was_impossible': False}),
#  Prediction(uid='379', iid='684', r_ui=4.0, est=3.969929800271981, details={'was_impossible': False}),
#  Prediction(uid='682', iid='223', r_ui=1.0, est=3.4514079899604844, details={'was_impossible': False}),
#  Prediction(uid='578', iid='258', r_ui=1.0, est=2.173672523236494, details={'was_impossible': False}),
#  Prediction(uid='916', iid='1428', r_ui=3.0, est=3.390100416621526, details={'was_impossible': False}),
#  Prediction(uid='929', iid='50', r_ui=4.0, est=4.003829969724578, details={'was_impossible': False}),
#  Prediction(uid='899', iid='144', r_ui=3.0, est=3.6545588161859746, details={'was_impossible': False}),
#  Prediction(uid='707', iid='151', r_ui=4.0, est=3.203697722482518, details={'was_impossible': False}),
#  Prediction(uid='130', iid='219', r_ui=5.0, est=3.70688714305117, details={'was_impossible': False}),
#  Prediction(uid='705', iid='82', r_ui=5.0, est=4.26014348781449, details={'was_impossible': False}),
#  Prediction(uid='59', iid='425', r_ui=4.0, est=4.218174905478482, details={'was_impossible': False}),
#  Prediction(uid='932', iid='170', r_ui=4.0, est=4.323101701445478, details={'was_impossible': False}),
#  Prediction(uid='428', iid='332', r_ui=4.0, est=4.065724429519448, details={'was_impossible': False}),
#  Prediction(uid='331', iid='1199', r_ui=1.0, est=1.6072753175431869, details={'was_impossible': False}),
#  Prediction(uid='280', iid='125', r_ui=2.0, est=3.361512036142862, details={'was_impossible': False}),
#  Prediction(uid='332', iid='118', r_ui=5.0, est=4.1634956824669445, details={'was_impossible': False}),
#  Prediction(uid='246', iid='469', r_ui=3.0, est=3.3519656921905936, details={'was_impossible': False}),
#  Prediction(uid='437', iid='582', r_ui=5.0, est=3.9452680827367717, details={'was_impossible': False}),
#  Prediction(uid='450', iid='417', r_ui=4.0, est=3.5259517964163845, details={'was_impossible': False}),
#  Prediction(uid='900', iid='284', r_ui=2.0, est=2.131528136270979, details={'was_impossible': False}),
#  Prediction(uid='640', iid='778', r_ui=4.0, est=4.057334328198426, details={'was_impossible': False}),
#  Prediction(uid='16', iid='31', r_ui=5.0, est=4.493786718594719, details={'was_impossible': False}),
#  Prediction(uid='10', iid='321', r_ui=4.0, est=3.689991603528252, details={'was_impossible': False}),
#  Prediction(uid='233', iid='47', r_ui=5.0, est=4.247292780118491, details={'was_impossible': False}),
#  Prediction(uid='625', iid='357', r_ui=3.0, est=3.834832027989221, details={'was_impossible': False}),
#  Prediction(uid='741', iid='56', r_ui=4.0, est=4.187977691082948, details={'was_impossible': False}),
#  Prediction(uid='650', iid='476', r_ui=2.0, est=2.4260997839430964, details={'was_impossible': False}),
#  Prediction(uid='308', iid='755', r_ui=3.0, est=3.1277416821588178, details={'was_impossible': False}),
#  Prediction(uid='201', iid='11', r_ui=4.0, est=3.3646689616239445, details={'was_impossible': False}),
#  Prediction(uid='87', iid='810', r_ui=3.0, est=3.342971572726222, details={'was_impossible': False}),
#  Prediction(uid='747', iid='462', r_ui=5.0, est=4.069574568323974, details={'was_impossible': False}),
#  Prediction(uid='393', iid='135', r_ui=1.0, est=3.1483483031767037, details={'was_impossible': False}),
#  Prediction(uid='425', iid='398', r_ui=1.0, est=1.5029907385653278, details={'was_impossible': False}),
#  Prediction(uid='311', iid='357', r_ui=5.0, est=4.297630057718906, details={'was_impossible': False}),
#  Prediction(uid='416', iid='1016', r_ui=5.0, est=3.8239880896847334, details={'was_impossible': False}),
#  Prediction(uid='659', iid='170', r_ui=3.0, est=3.969399834174061, details={'was_impossible': False}),
#  Prediction(uid='788', iid='601', r_ui=4.0, est=3.752541382647056, details={'was_impossible': False}),
#  Prediction(uid='551', iid='174', r_ui=4.0, est=4.061062632863631, details={'was_impossible': False}),
#  Prediction(uid='422', iid='50', r_ui=4.0, est=3.9819031073798326, details={'was_impossible': False}),
#  Prediction(uid='244', iid='97', r_ui=2.0, est=3.7894687307840327, details={'was_impossible': False}),
#  Prediction(uid='284', iid='903', r_ui=4.0, est=3.788832025732235, details={'was_impossible': False}),
#  Prediction(uid='37', iid='827', r_ui=3.0, est=2.8460802205510802, details={'was_impossible': False}),
#  Prediction(uid='362', iid='245', r_ui=4.0, est=3.607090185126888, details={'was_impossible': False}),
#  Prediction(uid='378', iid='370', r_ui=2.0, est=2.670248627976062, details={'was_impossible': False}),
#  Prediction(uid='465', iid='172', r_ui=3.0, est=3.4862928063530045, details={'was_impossible': False}),
#  Prediction(uid='655', iid='690', r_ui=2.0, est=2.9301966730486484, details={'was_impossible': False}),
#  Prediction(uid='217', iid='68', r_ui=3.0, est=3.2375441552954456, details={'was_impossible': False}),
#  Prediction(uid='401', iid='321', r_ui=2.0, est=2.6305069293380674, details={'was_impossible': False}),
#  Prediction(uid='657', iid='744', r_ui=4.0, est=3.5485247771761266, details={'was_impossible': False}),
#  Prediction(uid='889', iid='728', r_ui=3.0, est=2.8623200808262377, details={'was_impossible': False}),
#  Prediction(uid='423', iid='887', r_ui=5.0, est=4.292589056800725, details={'was_impossible': False}),
#  Prediction(uid='707', iid='425', r_ui=5.0, est=4.20643881423886, details={'was_impossible': False}),
#  Prediction(uid='738', iid='732', r_ui=3.0, est=3.6372724477396403, details={'was_impossible': False}),
#  Prediction(uid='146', iid='327', r_ui=3.0, est=3.3284799713884583, details={'was_impossible': False}),
#  Prediction(uid='921', iid='369', r_ui=1.0, est=2.7640509081977425, details={'was_impossible': False}),
#  Prediction(uid='749', iid='167', r_ui=2.0, est=3.0391844127011876, details={'was_impossible': False}),
#  Prediction(uid='181', iid='1358', r_ui=1.0, est=1.5774269177809064, details={'was_impossible': False}),
#  Prediction(uid='79', iid='313', r_ui=2.0, est=3.31348797584906, details={'was_impossible': False}),
#  Prediction(uid='514', iid='473', r_ui=3.0, est=2.883138401692335, details={'was_impossible': False}),
#  Prediction(uid='378', iid='972', r_ui=4.0, est=3.207498756380183, details={'was_impossible': False}),
#  Prediction(uid='197', iid='510', r_ui=5.0, est=4.480422492971698, details={'was_impossible': False}),
#  Prediction(uid='896', iid='64', r_ui=4.0, est=4.207083794848678, details={'was_impossible': False}),
#  Prediction(uid='458', iid='193', r_ui=4.0, est=3.9841035323782954, details={'was_impossible': False}),
#  Prediction(uid='593', iid='211', r_ui=4.0, est=3.9652683293070115, details={'was_impossible': False}),
#  Prediction(uid='384', iid='302', r_ui=5.0, est=4.780018623383805, details={'was_impossible': False}),
#  Prediction(uid='776', iid='218', r_ui=4.0, est=3.4409018857025595, details={'was_impossible': False}),
#  Prediction(uid='171', iid='310', r_ui=4.0, est=3.4622453149377277, details={'was_impossible': False}),
#  Prediction(uid='489', iid='245', r_ui=3.0, est=3.5421005147637126, details={'was_impossible': False}),
#  Prediction(uid='201', iid='676', r_ui=2.0, est=2.6835158479503365, details={'was_impossible': False}),
#  Prediction(uid='365', iid='846', r_ui=3.0, est=2.7915188917636735, details={'was_impossible': False}),
#  Prediction(uid='883', iid='216', r_ui=4.0, est=3.962242068017743, details={'was_impossible': False}),
#  Prediction(uid='220', iid='294', r_ui=4.0, est=3.944105641011724, details={'was_impossible': False}),
#  Prediction(uid='669', iid='657', r_ui=5.0, est=3.7364911329718486, details={'was_impossible': False}),
#  Prediction(uid='151', iid='628', r_ui=5.0, est=3.8746962545027226, details={'was_impossible': False}),
#  Prediction(uid='892', iid='576', r_ui=4.0, est=3.3744545970255535, details={'was_impossible': False}),
#  Prediction(uid='616', iid='315', r_ui=4.0, est=4.17825944011919, details={'was_impossible': False}),
#  Prediction(uid='42', iid='735', r_ui=4.0, est=3.930418709449867, details={'was_impossible': False}),
#  Prediction(uid='390', iid='713', r_ui=4.0, est=3.928679084472574, details={'was_impossible': False}),
#  Prediction(uid='665', iid='154', r_ui=3.0, est=3.55002212668348, details={'was_impossible': False}),
#  Prediction(uid='479', iid='455', r_ui=4.0, est=3.486566964778804, details={'was_impossible': False}),
#  Prediction(uid='380', iid='414', r_ui=2.0, est=3.2402189364026426, details={'was_impossible': False}),
#  Prediction(uid='532', iid='318', r_ui=5.0, est=5, details={'was_impossible': False}),
#  Prediction(uid='428', iid='301', r_ui=4.0, est=3.7277992531792408, details={'was_impossible': False}),
#  Prediction(uid='925', iid='245', r_ui=3.0, est=3.1519653946895994, details={'was_impossible': False}),
#  Prediction(uid='642', iid='794', r_ui=4.0, est=3.663212838949016, details={'was_impossible': False}),
#  Prediction(uid='851', iid='71', r_ui=4.0, est=3.5895793969901177, details={'was_impossible': False}),
#  Prediction(uid='395', iid='328', r_ui=4.0, est=3.7734896471515067, details={'was_impossible': False}),
#  Prediction(uid='268', iid='450', r_ui=1.0, est=1.5833327999926188, details={'was_impossible': False}),
#  Prediction(uid='18', iid='215', r_ui=3.0, est=3.4744605618486655, details={'was_impossible': False}),
#  Prediction(uid='364', iid='286', r_ui=5.0, est=4.292586399185119, details={'was_impossible': False}),
#  Prediction(uid='702', iid='258', r_ui=5.0, est=2.96054818178804, details={'was_impossible': False}),
#  Prediction(uid='416', iid='509', r_ui=5.0, est=4.0759724760254645, details={'was_impossible': False}),
#  Prediction(uid='488', iid='510', r_ui=4.0, est=3.612585770149586, details={'was_impossible': False}),
#  Prediction(uid='880', iid='97', r_ui=4.0, est=4.004608750975441, details={'was_impossible': False}),
#  Prediction(uid='821', iid='427', r_ui=5.0, est=4.877809468899101, details={'was_impossible': False}),
#  Prediction(uid='184', iid='215', r_ui=4.0, est=3.6069122503737234, details={'was_impossible': False}),
#  Prediction(uid='450', iid='121', r_ui=3.0, est=3.810529680822126, details={'was_impossible': False}),
#  Prediction(uid='95', iid='233', r_ui=4.0, est=3.168449189673932, details={'was_impossible': False}),
#  Prediction(uid='430', iid='123', r_ui=2.0, est=2.682896626873802, details={'was_impossible': False}),
#  Prediction(uid='321', iid='60', r_ui=4.0, est=3.860311596066839, details={'was_impossible': False}),
#  Prediction(uid='332', iid='70', r_ui=2.0, est=3.935765086943299, details={'was_impossible': False}),
#  Prediction(uid='880', iid='173', r_ui=3.0, est=4.025219956142346, details={'was_impossible': False}),
#  Prediction(uid='21', iid='858', r_ui=1.0, est=2.948717513127966, details={'was_impossible': False}),
#  Prediction(uid='294', iid='300', r_ui=4.0, est=3.5967524833110303, details={'was_impossible': False}),
#  Prediction(uid='342', iid='152', r_ui=4.0, est=3.7632420023644677, details={'was_impossible': False}),
#  Prediction(uid='919', iid='204', r_ui=4.0, est=3.6363507766698726, details={'was_impossible': False}),
#  Prediction(uid='682', iid='67', r_ui=4.0, est=3.1712355061694195, details={'was_impossible': False}),
#  Prediction(uid='573', iid='661', r_ui=4.0, est=3.8006774637361462, details={'was_impossible': False}),
#  Prediction(uid='194', iid='1011', r_ui=3.0, est=2.849856713135667, details={'was_impossible': False}),
#  Prediction(uid='655', iid='228', r_ui=3.0, est=3.135720123101123, details={'was_impossible': False}),
#  Prediction(uid='323', iid='203', r_ui=5.0, est=4.094948147617378, details={'was_impossible': False}),
#  ...]

# %%
algo.predict(uid=10, iid=100)
# Out:
# Prediction(uid=10, iid=100, r_ui=None, est=3.533397333013335, details={'was_impossible': False})
